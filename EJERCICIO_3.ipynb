# %% [markdown]
# ACTIVIDAD 3. SET DE EJERCICIOS. FERNANDO TORRES MEDINA

# %% [markdown]
# EJERCICIO 1. A. Definir y llamar. Complete la palabra clave que define una función.

# %%
def saludar():
  print("Hola")
saludar()
# Out:
# Hola

# %% [markdown]
# EJERCICIO 2. Llamar a la función. Complete la línea que ejecuta la función ya definida.

# %%
def bienvenida ():
  print("Bienvenia al curso")
bienvenida ()
# Out:
# Bienvenia al curso

# %% [markdown]
# EJERCICIO 3. Predice el orden de ejecución. Sin ejecutar, determine en qué orden aparecen los mensajes. EL ORDEN DE SALIDA ES B, A, C

# %% [markdown]
# EJERCICIO 4. Corrige el orden. El programa falla porque la función se llama antes de existir. Reescriba el bloque completo
# en el orden correcto.

# %%
def saludar(Ana):
  print("Hola,", Ana)
saludar("ANA")
# Out:
# Hola, ANA

# %% [markdown]
# EJERCICIO 5. Función con un parámetro. Complete el parámetro que recibe la función.

# %%
def saludar(Ana):
  print("Hola,", Ana)
saludar("Ana")
# Out:
# Hola, Ana

# %% [markdown]
# EJERCICIO 6. Función con dos parámetros. Complete los parámetros necesarios para calcular el área.

# %%
def area (base, altura):
  return base * altura
print(area(3, 4))
# Out:
# 12

# %% [markdown]
# EJERCICIO 7. Completa la llamada. Complete los argumentos para obtener exactamente el resultado indicado.

# %%
def area (base, altura):
  return base * altura
print(area(5,5)) # 25.0
# Out:
# 25

# %% [markdown]
# EJERCICIO 8. Reutilizar la misma función. Llame tres veces a la misma función con precios distintos.

# %%
def con_iva (precio):
  return precio * 1.19
print (con_iva(100))
print (con_iva(150))
print (con_iva (200))
# Out:
# 119.0
# 178.5
# 238.0

# %% [markdown]
# EJERCICIO 9. B. Parámetro o argumento. Observe la definición y la llamada, y distinga cada uno de los dos nombres. RESULTADO: n es el parámetro; 5 es el argumento.

# %% [markdown]
# EJERCICIO 10. Argumentos por posición. Complete la llamada para que se imprima: Ana 20 Bogota

# %%
def perfil (Nombre, edad, Ciudad):
  print("Ana", 20, "Bogota")

perfil("Ana", 20, "Bogota")
# Out:
# Ana 20 Bogota

# %% [markdown]
# EJERCICIO 11. Argumentos por nombre. Complete los nombres de los parámetros para que el orden deje de importar.

# %%
def perfil(nombre, edad, ciudad):
  print (nombre, edad, ciudad)
perfil(edad = 20, nombre = "Ana", ciudad = "Bogota")
# Out:
# Ana 20 Bogota

# %% [markdown]
# EJERCICIO 12. Valor por defecto. Complete el valor por defecto del parámetro saludo.

# %%
def saludar (nombre, saludo = "Hola"):
  print (saludo, nombre)
saludar ("Ana")
# Out:
# Hola Ana

# %% [markdown]
# EJERCICIO 13. Reemplazar el valor por defecto. Complete el argumento que sustituye al saludo por defecto.

# %%
def saludar(nombre, saludo = "Hola"):
  print (saludo, nombre)
saludar("Luis", "buen día")
# Out:
# buen día Luis

# %% [markdown]
# EJERCICIO 14. Orden de los parámetros. El siguiente encabezado produce un error. Reescriba la definición completa de forma
# correcta.

# %%
def registrar (producto, cantidad = 1):
  print (producto, cantidad)
registrar ("Leche")
# Out:
# Leche 1

# %% [markdown]
# EJERCICIO 15. Una lista como argumento. Complete el recorrido para sumar todos los precios recibidos.

# %%
def total (precios):
  suma = 0
  for p in precios:
    suma = suma + p
  return suma
print (total ([1200, 950, 3400]))
# Out:
# 5550

# %% [markdown]
# EJERCICIO 16. C. return y resultados. Complete la palabra clave que entrega el resultado.

# %%
def doble (n):
  return n*2
print (doble(5))
# Out:
# 10

# %% [markdown]
# EJERCICIO 17. Usar el valor devuelto. Complete la llamada para guardar el resultado y operar con él.

# %%
def doble(n):
  return n*2
resultado = doble(6)
print (resultado + 1)
# Out:
# 13

# %% [markdown]
# EJERCICIO 18. Función sin return. Sin ejecutar, determine qué imprimen las dos últimas líneas: LAS DOS ÚLTIMAS LINEAS IMPRIMEN EL SALUDO Y NONE.

# %% [markdown]
# EJERCICIO 19. print o return. La suma falla. Corrija la función para que el resultado pueda seguir usándose y escriba la
# versión corregida.

# %%
def doble (n):
  return (n*2)
total = doble (5) +3

# %% [markdown]
# EJERCICIO 20. return dentro de una condición. Complete la instrucción que devuelve el segundo resultado.

# %%
def signo (n):
  if n < 0:
    return "negativo"
print ("positivo")
print (signo(-4))
print (signo (7))
# Out:
# positivo
# negativo
# None

# %% [markdown]
# EJERCICIO 21. return termina la función. Sin ejecutar, determine qué se imprime y qué línea nunca se ejecuta. El resultado será: positivo
# La línea print("linea intermedia") nunca se ejecuta en este caso, y tampoco se ejecuta return "otro", porque el return "positivo" finaliza la función antes de llegar a ellas.

# %% [markdown]
# EJERCICIO 22. Devolver dos valores. Complete la función para que entregue el mínimo y el máximo.

# %%
def resumen(valores):
    return min(valores), max(valores)

menor, mayor = resumen ([8, 3, 10, 5])
print(menor, mayor)
# Out:
# 3 10

# %% [markdown]
# EJERCICIO 23. Encadenar funciones. Complete la llamada interna para calcular el precio con IVA redondeado.

# %%
def con_iva(p):
    return p * 1.19
def redondear(valor):
    return round(valor, 2)
print(redondear(con_iva(1200)))
# Out:
# 1428.0

# %% [markdown]
# EJERCICIO 24. D. Ámbito y colecciones. Sin ejecutar, determine qué imprime cada una de las dos llamadas. El resultado será: local, global

# %% [markdown]
# EJERCICIO 25. Evitar las variables globales. Reescriba la función para que reciba el IVA como parámetro y no dependa de una variable
# externa.

# %%
def con_iva(precio):
    iva = 0.19
    return precio * (1 + iva)

# %% [markdown]
# EJERCICIO 26. No modificar el original. Complete la función para que devuelva una lista nueva sin alterar la que recibe.

# %%
def agregar(lista):
      nueva = lista + [3]
      return nueva
datos = [1, 2]
print(agregar(datos))
print(datos)
# Out:
# [1, 2, 3]
# [1, 2]

# %% [markdown]
# EJERCICIO 27. Función que recibe una lista. Complete la función que calcula el promedio de una lista de notas.

# %%
def promedio(notas):
    total = 0
    for n in notas:
       total = total + n
    return total /len (notas)

print(promedio([3.5, 4.2, 2.8]))
# Out:
# 3.5

# %% [markdown]
# EJERCICO 28. Función que recibe un diccionario. Complete las claves para mostrar el nombre y la nota del estudiante.

# %%
def describir(alumno):
  print(alumno["nombre"], alumno["nota"])

describir({"nombre": "Laura", "nota": 4.6})
# Out:
# Laura 4.6

# %% [markdown]
# EJERCICIO 29. Función que devuelve una lista. Complete el método que agrega elementos y el valor que se devuelve.

# %%
def aprobados(estudiantes):
  resultado = []
  for e in estudiantes:
    if e["nota"] >= 3.0:
      resultado. append(e["nombre"])
  return resultado
datos = [{"nombre": "Ana", "nota": 4.2},
        {"nombre": "Luis", "nota": 2.8}]
print(aprobados(datos))
# Out:
# ['Ana']

# %% [markdown]
# EJE 30. RETO INTEGRADOR. Reporte de notas con funciones. Complete el programa que calcula el promedio de un estudiante, decide si aprueba y
# muestra el reporte usando tres funciones.

# %%
def promedio(notas):
    total = 0
    for n in notas:
      total = total + n
    return total / len(notas)
def aprueba(prom, minimo= 3.0):
  return prom >= minimo
def reporte(nombre, notas):
    prom = promedio(notas)
    print(nombre, round(prom, 2))
    if aprueba(prom):
      print("Aprobado")
    else:
     print("No aprobado")
reporte("Laura", [3.5, 4.2, 2.8])
# Out:
# Laura 3.5
# Aprobado
