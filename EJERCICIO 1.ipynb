# %% [markdown]
# FERNANDO TORRES MEDINA

# %% [markdown]
# Ejercicio 1. Completa la condición para mostrar “Mayor de edad” cuando la variable edad sea mayor o igual a 18

# %%
edad=20
if edad>=18:
  print("Mayor de edad")
# Out:
# Mayor de edd

# %% [markdown]
# Ejercicio 2.Completa la estructura para clasificar una temperatura como “Alta” si supera 30 grados y
# “Normal” en caso contrario.

# %%
temperatura = 32

if temperatura > 30:
    print("Alta")
else:
    print("Normal")
# Out:
# Alta

# %% [markdown]
# Ejercicio 3. Sin ejecutar, escribe exactamente qué imprimirá el programa.
# "IMPAR"

# %% [markdown]
# Ejercicio 4. Agrega las dos expresiones faltantes para clasificar la nota.

# %%
nota = 4.2

if nota >= 4.5:
    print("Excelente")
elif nota >= 4.0:
    print("Muy buen desempeño")
elif nota >= 3.0:
    print("Aprobado")
else:
    print("No aprobado")
# Out:
# Muy buen desempeño

# %% [markdown]
# Ejercicio 5. El programa pretende mostrar “Excelente” para notas de 4.5 o más. Reescribe únicamente el
# bloque condicional en el orden correcto.

# %%
if nota >= 4.5:
    print("Excelente")
elif nota >= 3.0:
    print("Aprobado")
# Out:
# Aprobado

# %% [markdown]
# Ejercicio 6. Escribe la salida para valor = 12. Después indica cuál condición fue la primera verdadera. RESPUESTA: elif valor < 15:
# print("C")

# %% [markdown]
# Ejercicio 7. Completa el operador lógico para permitir acceso solo cuando ambas variables sean
# verdaderas.

# %%
usuario_activo = True
tiene_permiso = True

if usuario_activo and tiene_permiso:
    print("Acceso permitido")
else:
    print("Acceso denegado")
# Out:
# Acceso permitido

# %% [markdown]
# Ejercicio 8. Completa la condición: se permite continuar si existe correo válido o teléfono válido.

# %%
correo_valido = False
telefono_valido = True

if correo_valido or telefono_valido:
    print("Continuar registro")
else:
    print("Faltan datos de contacto")
# Out:
# Continuar registro

# %% [markdown]
# Ejercicio 9. Completa la condición usando not para mostrar el mensaje solo si la cuenta NO está
# bloqueada.

# %%
cuenta_bloqueada = False

if not cuenta_bloqueada:
    print("Puede operar")
# Out:
# Puede operar

# %% [markdown]
# Ejercicio 10. Completa range() para imprimir los valores 1, 2, 3, 4 y 5.

# %%
for numero in range(1, 6):
    print(numero)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Ejercicio 11. Completa range() para imprimir 2, 4, 6, 8 y 10

# %%
for numero in range(2, 11, 2):
    print(numero)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# Ejercico 12. Sin ejecutar, determina el valor final de suma. LA RESPUESTA ES SEIS EN LA MEDIDA QUE VA ACUMULANDO =0+1=1, 1+2=3, 3+3=6

# %% [markdown]
# Ejercicio 13. Completa la condición y la actualización para imprimir los números del 1 al 5.

# %%
numero = 1

while numero <= 5:
    print(numero)
    numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Ejercicio 14. El siguiente programa nunca termina. Corrige solo la línea que falta dentro del ciclo. Respuesta: número = número +1

# %% [markdown]
# Ejercicio 15. Completa el ciclo para permitir máximo 3 intentos. No modifiques las líneas ya escritas.

# %% [markdown]
# Ejercicio 16. Escribe la estructura que elegirías en cada situación.Procesar exactamente 10 mediciones: (for). Pedir una clave hasta que sea correcta: (while). Imprimir los números del 1 al 20: (for). Repetir un cálculo hasta que el error sea menor que 0.01: while.

# %% [markdown]
# Ejercicio 17. Completa el programa para recorrer del 1 al 12 y mostrar únicamente los múltiplos de 3.

# %%
for numero in range(1, 13):
    if numero % 3 == 0:
        print(numero)
# Out:
# 3
# 6
# 9
# 12

# %% [markdown]
# Ejercicio 18. Escribe todas las líneas que producirá el programa. 1 A, 2A, 3B, 4B, 5B, 6C Y 7C.

# %% [markdown]
# Ejercicio 19. Completa el código Python para que represente exactamente el pseudocódigo mostrado.

# %%
nota = float(input("Nota: "))

if nota >= 3.0:
    print("Aprobado")
else:
    print("No aprobado")
# Out:
# Nota: 4.2
# Aprobado

# %% [markdown]
# Ejercicio 20. Completa el programa Python equivalente al pseudocódigo.

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# RETO INTERGADOR. Clasificación de temperaturas

# %%
for i in range(5):
    t = float(input("Temperatura: "))

    if t < 18:
        print("Baja")
    elif t <= 25:
        print("Normal")
    else:
        print("Alta")
# Out:
# Temperatura: 15
# Baja
# Temperatura: 18
# Normal
